# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df =pd.read_csv("../data/cleaned_owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0         8041.025775           0.0         0.0            72.060873  ...
# 1         8041.025775           0.0         0.0            72.060873  ...
# 2         8041.025775           0.0         0.0            72.060873  ...
# 3         8041.025775           0.0         0.0            72.060873  ...
# 4         8041.025775           0.0         0.0            72.060873  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# show bar graph for continents and total deaths
plt.bar(df["continent"],df['new_deaths_per_million'])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='total_cases', y='continent', data=df, hue="date", style='date')
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()
